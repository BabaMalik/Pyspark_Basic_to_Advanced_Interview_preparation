# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
.appName("Learning_Spark_Basics")\
.master("local[*]")\
.getOrCreate()

# Test the Spark Session
print("Spark Session Initialized")
print("Spark Version:", spark.version)
print("Hive Enabled:", spark.conf.get("spark.sql.catalogImplementation"))
# Out:
# Spark Session Initialized
# Spark Version: 3.5.4
# Hive Enabled: in-memory

# %% [markdown]
# #### 1. How do you create a DataFrame in PySpark? Write code to create a DataFrame from a list and a CSV file.

# %%
# Define the data
data = [
    ["1", "2020-01-01", "pending"],
    ["2", "2020-01-02", "shipped"],
    ["3", "2020-01-03", "delivered"]
]

# %%
# Define the column names
columns = ["customer_id", "order_date", "order_status"]

# %%
df = spark.createDataFrame(data, columns)

# %%
df.show(5)
# Out:
# +-----------+----------+------------+
# |customer_id|order_date|order_status|
# +-----------+----------+------------+
# |          1|2020-01-01|     pending|
# |          2|2020-01-02|     shipped|
# |          3|2020-01-03|   delivered|
# +-----------+----------+------------+

# %%
df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders_schema ="customerid long,order_date string,customer_id long,order_status string"

# %%
df = spark.read.csv("orders_1gb.csv",schema=orders_schema)

# %%
df.show(5)
# Out:
# +----------+--------------------+-----------+---------------+
# |customerid|          order_date|customer_id|   order_status|
# +----------+--------------------+-----------+---------------+
# |         1|2013-07-25 00:00:...|      11599|         CLOSED|
# |         2|2013-07-25 00:00:...|        256|PENDING_PAYMENT|
# |         3|2013-07-25 00:00:...|      12111|       COMPLETE|
# |         4|2013-07-25 00:00:...|       8827|         CLOSED|
# |         5|2013-07-25 00:00:...|      11318|       COMPLETE|
# +----------+--------------------+-----------+---------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- customerid: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df.rdd.getNumPartitions()
# Out:
# 10

# %% [markdown]
# #### 2. Explain the difference between `groupBy` and `reduceByKey` in PySpark with examples.

# %% [markdown]
# #### 3. How can you handle missing values in a PySpark DataFrame? Write code to replace null values with a default value.

# %% [markdown]
# #### 4. What is the difference between `cache()` and `persist()` in PySpark? Provide examples.

# %% [markdown]
# #### 5. How do you perform joins in PySpark? Write code for inner, left, and full outer joins with sample data.

# %% [markdown]
# #### 6. How can you remove duplicate rows in a PySpark DataFrame? Write code to delete duplicates based on a specific column.

# %% [markdown]
# #### 7. Explain the difference between `map` and `flatMap` in PySpark with examples.

# %% [markdown]
# #### 8. How can you optimize PySpark jobs? Discuss broadcast variables, partitioning, and serialization with examples.

# %% [markdown]
# #### 9. Write a PySpark program to calculate the top N products based on sales from a given DataFrame.

# %% [markdown]
# #### 10. How can you write data into different file formats like Parquet, JSON, and CSV in PySpark? Provide examples for each.

# %%
spark.stop()
